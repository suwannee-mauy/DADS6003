# %% [markdown]
# <a href="https://colab.research.google.com/github/suwannee-mauy/DADS6003/blob/main/Copy_of_6620422030_Assignment3_Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data_1 = pd.read_csv('https://raw.githubusercontent.com/suwannee-mauy/DADS6003/main/Smartphone_(Responses).csv')
data_1.head(3)
# Out:
#             Timestamp เพศของผู้ตอบแบบสอบถาม ช่วงอายุของผู้ตอบแบบสอบถาม  \
# 0  1/13/2024 14:30:33                   ชาย                   26-30 ปี
# 1  1/13/2024 14:41:25                  หญิง                   21-25 ปี
# 2  1/13/2024 15:01:08                   ชาย                   26-30 ปี
#
#   อาชีพของผู้ตอบแบบสอบถาม ช่วงเงินเดือนของผู้ตอบแบบสอบถาม  \
# 0                   เอกชน               30,001-40,000 บาท
# 1                   เอกชน               40,001-50,000 บาท
# 2                   เอกชน               30,001-40,000 บาท
#
#   ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด  \
# 0                          IOS และ Andriod
# 1                                      IOS
# 2                                      IOS
#
#   ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]  \
# 0                                     น้อยที่สุด
# 1                                      บ่อยครั้ง
# 2                                   ค่อนข้างน้อย
#
#   ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นโซเชี่ยลมีเดีย]  \
# 0                                            ปานกลาง
# 1                                         บ่อยที่สุด
# 2                                         บ่อยที่สุด
#
#   ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ดูหนัง ฟังเพลง]  \
# 0                                       ค่อนข้างน้อย
# 1                                            ปานกลาง
# 2                                            ปานกลาง
#
#   ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]  \
# 0                                       ค่อนข้างน้อย
# 1                                       ค่อนข้างน้อย
# 2                                            ปานกลาง
#
#   หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด  \
# 0                                             Iphone
# 1                                             Iphone
# 2                                             Iphone
#
#   จากข้อที่แล้ว เนื่องจากสาเหตุใด
# 0    apple ecosystem ทั้งบ้านแล้ว
# 1                       ดูรวยดีย์
# 2                      ความเสถียร

# %%
columns = ['เพศของผู้ตอบแบบสอบถาม',
 'ช่วงอายุของผู้ตอบแบบสอบถาม',
 'อาชีพของผู้ตอบแบบสอบถาม',
 'ช่วงเงินเดือนของผู้ตอบแบบสอบถาม',
 'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]',
 'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นโซเชี่ยลมีเดีย]',
 'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ดูหนัง ฟังเพลง]',
 'ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]',
 'หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด']

# %%
# Drop Field ที่ไม่ใช้
data_2 = data_1.drop(['Timestamp','จากข้อที่แล้ว เนื่องจากสาเหตุใด'], axis=1)
data_2.shape
# Out:
# (75, 10)

# %%
# Filter เฉพาะที่เป็น IOS หรือ Android
data_3 = data_2[(data_2['ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด'] == 'IOS') | (data_2['ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด'] == 'Android')]
data_3.head(3)
# Out:
#   เพศของผู้ตอบแบบสอบถาม ช่วงอายุของผู้ตอบแบบสอบถาม อาชีพของผู้ตอบแบบสอบถาม  \
# 1                  หญิง                   21-25 ปี                   เอกชน
# 2                   ชาย                   26-30 ปี                   เอกชน
# 3                   ชาย                   31-35 ปี                   เอกชน
#
#   ช่วงเงินเดือนของผู้ตอบแบบสอบถาม ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด  \
# 1               40,001-50,000 บาท                                      IOS
# 2               30,001-40,000 บาท                                      IOS
# 3               40,001-50,000 บาท                                      IOS
#
#   ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]  \
# 1                                      บ่อยครั้ง
# 2                                   ค่อนข้างน้อย
# 3                                     น้อยที่สุด
#
#   ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นโซเชี่ยลมีเดีย]  \
# 1                                         บ่อยที่สุด
# 2                                         บ่อยที่สุด
# 3                                            ปานกลาง
#
#   ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ดูหนัง ฟังเพลง]  \
# 1                                            ปานกลาง
# 2                                            ปานกลาง
# 3                                            ปานกลาง
#
#   ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]  \
# 1                                       ค่อนข้างน้อย
# 2                                            ปานกลาง
# 3                                         น้อยที่สุด
#
#   หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด
# 1                                             Iphone
# 2                                             Iphone
# 3                                             Iphone

# %%
# แปลงค่า
data_3 = pd.get_dummies(data_3, columns=columns)
data_3.head(3)
# Out:
#   ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด  เพศของผู้ตอบแบบสอบถาม_-  \
# 1                                      IOS                    False
# 2                                      IOS                    False
# 3                                      IOS                    False
#
#    เพศของผู้ตอบแบบสอบถาม_ชาย  เพศของผู้ตอบแบบสอบถาม_หญิง  \
# 1                      False                        True
# 2                       True                       False
# 3                       True                       False
#
#    ช่วงอายุของผู้ตอบแบบสอบถาม_21-25 ปี  ช่วงอายุของผู้ตอบแบบสอบถาม_26-30 ปี  \
# 1                                 True                                False
# 2                                False                                 True
# 3                                False                                False
#
#    ช่วงอายุของผู้ตอบแบบสอบถาม_31-35 ปี  ช่วงอายุของผู้ตอบแบบสอบถาม_36-40 ปี  \
# 1                                False                                False
# 2                                False                                False
# 3                                 True                                False
#
#    อาชีพของผู้ตอบแบบสอบถาม_.  อาชีพของผู้ตอบแบบสอบถาม_Freelancer  ...  \
# 1                      False                               False  ...
# 2                      False                               False  ...
# 3                      False                               False  ...
#
#    ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]_บ่อยครั้ง  \
# 1                                              False
# 2                                              False
# 3                                              False
#
#    ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]_บ่อยที่สุด  \
# 1                                              False
# 2                                              False
# 3                                              False
#
#    ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]_ปานกลาง  \
# 1                                              False
# 2                                               True
# 3                                              False
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Google  \
# 1                                              False
# 2                                              False
# 3                                              False
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Iphone  \
# 1                                               True
# 2                                               True
# 3                                               True
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Nokia  \
# 1                                              False
# 2                                              False
# 3                                              False
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Oneplus  \
# 1                                              False
# 2                                              False
# 3                                              False
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Oppo  \
# 1                                              False
# 2                                              False
# 3                                              False
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Samsung  \
# 1                                              False
# 2                                              False
# 3                                              False
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_ยังไม่รู้
# 1                                              False
# 2                                              False
# 3                                              False
#
# [3 rows x 48 columns]

# %%
data_3 = data_3.replace({True: 1, False: 0})
data_3.head(3)
# Out:
#   ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด  เพศของผู้ตอบแบบสอบถาม_-  \
# 1                                      IOS                        0
# 2                                      IOS                        0
# 3                                      IOS                        0
#
#    เพศของผู้ตอบแบบสอบถาม_ชาย  เพศของผู้ตอบแบบสอบถาม_หญิง  \
# 1                          0                           1
# 2                          1                           0
# 3                          1                           0
#
#    ช่วงอายุของผู้ตอบแบบสอบถาม_21-25 ปี  ช่วงอายุของผู้ตอบแบบสอบถาม_26-30 ปี  \
# 1                                    1                                    0
# 2                                    0                                    1
# 3                                    0                                    0
#
#    ช่วงอายุของผู้ตอบแบบสอบถาม_31-35 ปี  ช่วงอายุของผู้ตอบแบบสอบถาม_36-40 ปี  \
# 1                                    0                                    0
# 2                                    0                                    0
# 3                                    1                                    0
#
#    อาชีพของผู้ตอบแบบสอบถาม_.  อาชีพของผู้ตอบแบบสอบถาม_Freelancer  ...  \
# 1                          0                                   0  ...
# 2                          0                                   0  ...
# 3                          0                                   0  ...
#
#    ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]_บ่อยครั้ง  \
# 1                                                  0
# 2                                                  0
# 3                                                  0
#
#    ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]_บ่อยที่สุด  \
# 1                                                  0
# 2                                                  0
# 3                                                  0
#
#    ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]_ปานกลาง  \
# 1                                                  0
# 2                                                  1
# 3                                                  0
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Google  \
# 1                                                  0
# 2                                                  0
# 3                                                  0
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Iphone  \
# 1                                                  1
# 2                                                  1
# 3                                                  1
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Nokia  \
# 1                                                  0
# 2                                                  0
# 3                                                  0
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Oneplus  \
# 1                                                  0
# 2                                                  0
# 3                                                  0
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Oppo  \
# 1                                                  0
# 2                                                  0
# 3                                                  0
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Samsung  \
# 1                                                  0
# 2                                                  0
# 3                                                  0
#
#    หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_ยังไม่รู้
# 1                                                  0
# 2                                                  0
# 3                                                  0
#
# [3 rows x 48 columns]

# %%
# แทนค่า "IOS": 1, 'Android': 0
data_3['ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด'] = data_3["ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด"].replace({"IOS": 1, "Android": 0})
data_3.info()  #เช็ค null
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71 entries, 1 to 74
# Data columns (total 48 columns):
#  #   Column                                                                     Non-Null Count  Dtype
# ---  ------                                                                     --------------  -----
#  0   ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด                                   71 non-null     int64
#  1   เพศของผู้ตอบแบบสอบถาม_-                                                    71 non-null     int64
#  2   เพศของผู้ตอบแบบสอบถาม_ชาย                                                  71 non-null     int64
#  3   เพศของผู้ตอบแบบสอบถาม_หญิง                                                 71 non-null     int64
#  4   ช่วงอายุของผู้ตอบแบบสอบถาม_21-25 ปี                                        71 non-null     int64
#  5   ช่วงอายุของผู้ตอบแบบสอบถาม_26-30 ปี                                        71 non-null     int64
#  6   ช่วงอายุของผู้ตอบแบบสอบถาม_31-35 ปี                                        71 non-null     int64
#  7   ช่วงอายุของผู้ตอบแบบสอบถาม_36-40 ปี                                        71 non-null     int64
#  8   อาชีพของผู้ตอบแบบสอบถาม_.                                                  71 non-null     int64
#  9   อาชีพของผู้ตอบแบบสอบถาม_Freelancer                                         71 non-null     int64
#  10  อาชีพของผู้ตอบแบบสอบถาม_ข้าราชการ                                          71 non-null     int64
#  11  อาชีพของผู้ตอบแบบสอบถาม_นักศึกษา                                           71 non-null     int64
#  12  อาชีพของผู้ตอบแบบสอบถาม_รัฐวิสาหกิจ                                        71 non-null     int64
#  13  อาชีพของผู้ตอบแบบสอบถาม_ว่างงาน                                            71 non-null     int64
#  14  อาชีพของผู้ตอบแบบสอบถาม_เอกชน                                              71 non-null     int64
#  15  ช่วงเงินเดือนของผู้ตอบแบบสอบถาม_20,001-30,000 บาท                          71 non-null     int64
#  16  ช่วงเงินเดือนของผู้ตอบแบบสอบถาม_30,001-40,000 บาท                          71 non-null     int64
#  17  ช่วงเงินเดือนของผู้ตอบแบบสอบถาม_40,001-50,000 บาท                          71 non-null     int64
#  18  ช่วงเงินเดือนของผู้ตอบแบบสอบถาม_50,001-60,000 บาท                          71 non-null     int64
#  19  ช่วงเงินเดือนของผู้ตอบแบบสอบถาม_น้อยกว่า 20,000 บาท                        71 non-null     int64
#  20  ช่วงเงินเดือนของผู้ตอบแบบสอบถาม_มากกว่า 60,000 บาท                         71 non-null     int64
#  21  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]_ค่อนข้างน้อย                71 non-null     int64
#  22  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]_น้อยที่สุด                  71 non-null     int64
#  23  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]_บ่อยครั้ง                   71 non-null     int64
#  24  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]_บ่อยที่สุด                  71 non-null     int64
#  25  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นเกม]_ปานกลาง                     71 non-null     int64
#  26  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นโซเชี่ยลมีเดีย]_ค่อนข้างน้อย     71 non-null     int64
#  27  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นโซเชี่ยลมีเดีย]_น้อยที่สุด       71 non-null     int64
#  28  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นโซเชี่ยลมีเดีย]_บ่อยครั้ง        71 non-null     int64
#  29  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นโซเชี่ยลมีเดีย]_บ่อยที่สุด       71 non-null     int64
#  30  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [เล่นโซเชี่ยลมีเดีย]_ปานกลาง          71 non-null     int64
#  31  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ดูหนัง ฟังเพลง]_ค่อนข้างน้อย         71 non-null     int64
#  32  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ดูหนัง ฟังเพลง]_น้อยที่สุด           71 non-null     int64
#  33  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ดูหนัง ฟังเพลง]_บ่อยครั้ง            71 non-null     int64
#  34  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ดูหนัง ฟังเพลง]_บ่อยที่สุด           71 non-null     int64
#  35  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ดูหนัง ฟังเพลง]_ปานกลาง              71 non-null     int64
#  36  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]_ค่อนข้างน้อย     71 non-null     int64
#  37  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]_น้อยที่สุด       71 non-null     int64
#  38  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]_บ่อยครั้ง        71 non-null     int64
#  39  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]_บ่อยที่สุด       71 non-null     int64
#  40  ท่านใช้สมาร์ทโฟนในการทำอะไรมากที่สุด [ถ่ายรูป ถ่ายวิดีโอ]_ปานกลาง          71 non-null     int64
#  41  หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Google     71 non-null     int64
#  42  หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Iphone     71 non-null     int64
#  43  หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Nokia      71 non-null     int64
#  44  หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Oneplus    71 non-null     int64
#  45  หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Oppo       71 non-null     int64
#  46  หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_Samsung    71 non-null     int64
#  47  หากท่านซื้อสมาร์ทโฟนเครื่องใหม่ จะใช้เลือกซื้อสมาร์ทโฟนแบรนด์ใด_ยังไม่รู้  71 non-null     int64
# dtypes: int64(48)
# memory usage: 27.2 KB

# %%
# !pip install shap
# Out:
# Collecting shap
#   Downloading shap-0.46.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from shap) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from shap) (1.13.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from shap) (1.3.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from shap) (2.1.4)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.10/dist-packages (from shap) (4.66.5)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.10/dist-packages (from shap) (24.1)
# Collecting slicer==0.0.8 (from shap)
#   Downloading slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from shap) (2.2.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->shap) (2024.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->shap) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.16.0)
# Downloading shap-0.46.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (540 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 540.1/540.1 kB 6.7 MB/s eta 0:00:00
# Downloading slicer-0.0.8-py3-none-any.whl (15 kB)
# Installing collected packages: slicer, shap
# Successfully installed shap-0.46.0 slicer-0.0.8

# %%
import pandas as pd
import numpy as np
import shap
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

X = data_3.drop(['ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด'], axis=1)
y = data_3['ปัจจุบันท่านใช้สมาร์ทโฟนระบบปฎิบัติการใด']

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=25)

# Create a logistic regression model
logistic_model = LogisticRegression()

# Train a Logistic regression model
logistic_model.fit(X_train, y_train)

# Test the model
accuracy = logistic_model.score(X_test, y_test)
accuracy
# Out:
# 0.9090909090909091

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# !wget -q https://github.com/google/fonts/raw/main/ofl/sarabun/Sarabun-Regular.ttf
mpl.font_manager.fontManager.addfont('Sarabun-Regular.ttf')
mpl.rc('font', family='Sarabun')
plt.rcParams ['font.family'] = ('Sarabun')

# %%
import shap
from sklearn.metrics import classification_report

print(classification_report(y_test, logistic_model.predict(X_test)))

explainer = shap.Explainer(logistic_model, X_train, feature_names=data_3.columns.tolist())
shap_values = explainer(X_test)

shap.plots.initjs()
shap.plots.beeswarm(shap_values)
shap.plots
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         4
#            1       0.90      1.00      0.95        18
#
#     accuracy                           0.91        22
#    macro avg       0.95      0.75      0.81        22
# weighted avg       0.92      0.91      0.90        22
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <module 'shap.plots' from '/usr/local/lib/python3.10/dist-packages/shap/plots/__init__.py'>

# %%
 shap.plots.waterfall(shap_values[0])

# %%
shap.initjs()
shap.plots.force(shap_values[0])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i1EULPVPXL3657CK8UK03'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 1.9256432613177656, "outValue": 3.3862483230333016, "link": "identity", "featureNames": ["\u0e40\u0e1e\u0e28\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_-", "\u0e40\u0e1e\u0e28\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_\u0e0a\u0e32\u0e22", "\u0e40\u0e1e\u0e28\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_\u0e2b\u0e0d\u0e34\u0e07", "\u0e0a\u0e48\u0e27\u0e07\u0e2d\u0e32\u0e22\u0e38\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_21-25 \u0e1b\u0e35", "\u0e0a\u0e48\u0e27\u0e07\u0e2d\u0e32\u0e22\u0e38\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_26-30 \u0e1b\u0e35", "\u0e0a\u0e48\u0e27\u0e07\u0e2d\u0e32\u0e22\u0e38\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_31-35 \u0e1b\u0e35", "\u0e0a\u0e48\u0e27\u0e07\u0e2d\u0e32\u0e22\u0e38\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_36-40 \u0e1b\u0e35", "\u0e2d\u0e32\u0e0a\u0e35\u0e1e\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_.", "\u0e2d\u0e32\u0e0a\u0e35\u0e1e\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_Freelancer", "\u0e2d\u0e32\u0e0a\u0e35\u0e1e\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_\u0e02\u0e49\u0e32\u0e23\u0e32\u0e0a\u0e01\u0e32\u0e23", "\u0e2d\u0e32\u0e0a\u0e35\u0e1e\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_\u0e19\u0e31\u0e01\u0e28\u0e36\u0e01\u0e29\u0e32", "\u0e2d\u0e32\u0e0a\u0e35\u0e1e\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_\u0e23\u0e31\u0e10\u0e27\u0e34\u0e2a\u0e32\u0e2b\u0e01\u0e34\u0e08", "\u0e2d\u0e32\u0e0a\u0e35\u0e1e\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_\u0e27\u0e48\u0e32\u0e07\u0e07\u0e32\u0e19", "\u0e2d\u0e32\u0e0a\u0e35\u0e1e\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_\u0e40\u0e2d\u0e01\u0e0a\u0e19", "\u0e0a\u0e48\u0e27\u0e07\u0e40\u0e07\u0e34\u0e19\u0e40\u0e14\u0e37\u0e2d\u0e19\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_20,001-30,000 \u0e1a\u0e32\u0e17", "\u0e0a\u0e48\u0e27\u0e07\u0e40\u0e07\u0e34\u0e19\u0e40\u0e14\u0e37\u0e2d\u0e19\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_30,001-40,000 \u0e1a\u0e32\u0e17", "\u0e0a\u0e48\u0e27\u0e07\u0e40\u0e07\u0e34\u0e19\u0e40\u0e14\u0e37\u0e2d\u0e19\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_40,001-50,000 \u0e1a\u0e32\u0e17", "\u0e0a\u0e48\u0e27\u0e07\u0e40\u0e07\u0e34\u0e19\u0e40\u0e14\u0e37\u0e2d\u0e19\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_50,001-60,000 \u0e1a\u0e32\u0e17", "\u0e0a\u0e48\u0e27\u0e07\u0e40\u0e07\u0e34\u0e19\u0e40\u0e14\u0e37\u0e2d\u0e19\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_\u0e19\u0e49\u0e2d\u0e22\u0e01\u0e27\u0e48\u0e32 20,000 \u0e1a\u0e32\u0e17", "\u0e0a\u0e48\u0e27\u0e07\u0e40\u0e07\u0e34\u0e19\u0e40\u0e14\u0e37\u0e2d\u0e19\u0e02\u0e2d\u0e07\u0e1c\u0e39\u0e49\u0e15\u0e2d\u0e1a\u0e41\u0e1a\u0e1a\u0e2a\u0e2d\u0e1a\u0e16\u0e32\u0e21_\u0e21\u0e32\u0e01\u0e01\u0e27\u0e48\u0e32 60,000 \u0e1a\u0e32\u0e1 ...

# %%
shap.decision_plot(explainer.expected_value,
                   explainer.shap_values(X),
                   feature_names = list(X.columns))
